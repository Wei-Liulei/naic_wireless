# %% [markdown]
# # 运行代码

# %%
# %run run.py
# Out:
# 00:38:25 _load_data start running ...
# 00:38:36 _load_data costed 10.42 Sec
# load mode weight from ./model/temp/project53.27
#
# 00:38:36 _load_model start running ...
# 00:38:37 _load_model costed 0.92 Sec
#
# 00:38:37 _fit start running ...
# Epoch 1/50
# 63/63 [==============================] - 12s 171ms/step - loss: 8.5941e-05 - nmse: 57.1106 - val_loss: 9.5982e-05 - val_nmse: 52.6209
# Epoch 2/50
# 63/63 [==============================] - 8s 124ms/step - loss: 7.9499e-05 - nmse: 60.2315 - val_loss: 9.5911e-05 - val_nmse: 52.6565
# Epoch 3/50
# 63/63 [==============================] - 8s 124ms/step - loss: 7.8856e-05 - nmse: 60.5655 - val_loss: 9.6045e-05 - val_nmse: 52.5897
# Epoch 4/50
# 63/63 [==============================] - 8s 124ms/step - loss: 7.9299e-05 - nmse: 60.3178 - val_loss: 9.6582e-05 - val_nmse: 52.3229
# Epoch 5/50
# 63/63 [==============================] - 8s 126ms/step - loss: 7.9167e-05 - nmse: 60.5434 - val_loss: 9.6778e-05 - val_nmse: 52.2275
# ...

# %%
# %run run.py
# Out:
# 01:03:50 _load_data start running ...
# 01:04:01 _load_data costed 10.49 Sec
# load mode weight from ./model/temp/project53.41
#
# 01:04:01 _load_model start running ...
# 01:04:01 _load_model costed 0.42 Sec
#
# 01:04:01 _fit start running ...
# Epoch 1/100
# 63/63 [==============================] - 12s 180ms/step - loss: 8.5655e-05 - nmse: 57.2519 - val_loss: 9.5858e-05 - val_nmse: 52.6821
# Epoch 2/100
# 63/63 [==============================] - 8s 124ms/step - loss: 7.8382e-05 - nmse: 60.7907 - val_loss: 9.5815e-05 - val_nmse: 52.7032
# Epoch 3/100
# 63/63 [==============================] - 8s 126ms/step - loss: 7.7710e-05 - nmse: 61.1380 - val_loss: 9.5951e-05 - val_nmse: 52.6364
# Epoch 4/100
# 63/63 [==============================] - 8s 124ms/step - loss: 7.8200e-05 - nmse: 60.8670 - val_loss: 9.5968e-05 - val_nmse: 52.6270
# Epoch 5/100
# 63/63 [==============================] - 8s 124ms/step - loss: 7.7810e-05 - nmse: 61.2201 - val_loss: 9.7055e-05 - val_nmse: 52.0914
# ...

# %%
# %run run.py
# Out:
# 01:19:29 _load_data start running ...
# 01:19:40 _load_data costed 11.45 Sec
# load mode weight from ./model/temp/project53.51
#
# 01:19:41 _load_model start running ...
# 01:19:41 _load_model costed 0.21 Sec
#
# 01:19:41 _fit start running ...
# Epoch 1/300
# 63/63 [==============================] - 13s 173ms/step - loss: 8.3131e-05 - nmse: 58.5298 - val_loss: 9.5275e-05 - val_nmse: 52.9693
# Epoch 2/300
# 63/63 [==============================] - 8s 125ms/step - loss: 7.6349e-05 - nmse: 61.8095 - val_loss: 9.5365e-05 - val_nmse: 52.9250
# Epoch 3/300
# 63/63 [==============================] - 8s 125ms/step - loss: 7.5756e-05 - nmse: 62.1175 - val_loss: 9.5349e-05 - val_nmse: 52.9321
# Epoch 4/300
# 63/63 [==============================] - 8s 124ms/step - loss: 7.6184e-05 - nmse: 61.8764 - val_loss: 9.5541e-05 - val_nmse: 52.8351
# Epoch 5/300
# 63/63 [==============================] - 8s 125ms/step - loss: 7.5677e-05 - nmse: 62.2848 - val_loss: 9.5584e-05 - val_nmse: 52.8151
# ...

# %%
# %run run.py
# Out:
# 02:08:23 _load_data start running ...
# 02:08:33 _load_data costed 10.26 Sec
# load mode weight from ./model/temp/project54.1
#
# 02:08:33 _load_model start running ...
# 02:08:34 _load_model costed 0.15 Sec
#
# 02:08:34 _fit start running ...
# Epoch 1/300
# 63/63 [==============================] - 12s 164ms/step - loss: 8.1804e-05 - nmse: 59.1639 - val_loss: 9.3637e-05 - val_nmse: 53.7675
#
# Epoch 00001: val_nmse improved from -inf to 53.76751, saving model to ./model/checkpoint/nmse_53.77.hdf5
# Epoch 2/300
# 63/63 [==============================] - 8s 123ms/step - loss: 7.1190e-05 - nmse: 64.3943 - val_loss: 9.3655e-05 - val_nmse: 53.7582
#
# Epoch 00002: val_nmse did not improve from 53.76751
# Epoch 3/300
# 63/63 [==============================] - 8s 124ms/step - loss: 7.0754e-05 - nmse: 64.6208 - val_loss: 9.3788e-05 - val_nmse: 53.6912
#
# Epoch 00003: val_nmse did not improve from 53.76751
# Epoch 4/300
# ...

# %%
# %run run.py
# Out:
# 03:00:59 _load_data start running ...
# 03:01:09 _load_data costed 10.23 Sec
# load mode weight from ./model/checkpoint
#
# 03:01:09 _load_model start running ...
# 03:01:10 _load_model costed 0.14 Sec
#
# 03:01:10 _fit start running ...
# Epoch 1/300
# 63/63 [==============================] - 11s 164ms/step - loss: 7.9163e-05 - nmse: 60.4790 - val_loss: 9.2156e-05 - val_nmse: 54.4924
#
# Epoch 00001: val_nmse improved from -inf to 54.49239, saving model to ./model/checkpoint/nmse_54.49.hdf5
# Epoch 2/300
# 63/63 [==============================] - 8s 125ms/step - loss: 6.6910e-05 - nmse: 66.5368 - val_loss: 9.2033e-05 - val_nmse: 54.5524
#
# Epoch 00002: val_nmse improved from 54.49239 to 54.55236, saving model to ./model/checkpoint/nmse_54.55.hdf5
# Epoch 3/300
# 63/63 [==============================] - 8s 123ms/step - loss: 6.6431e-05 - nmse: 66.7837 - val_loss: 9.2082e-05 - val_nmse: 54.5275
#
# Epoch 00003: val_nmse did not improve from 54.55236
# Epoch 4/300
# ...

# %% [markdown]
# # 结果作图

# %%
from utils import plot_x, plot_results
plot_results(t.x_test, t.y_test, 5, 10)
# plot_3dheat(t.x_test, 10)
